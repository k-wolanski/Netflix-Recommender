# %% [markdown]
# # Netflix Recommendation System
# In this notebook I will be following a tutorial on how to create a netflix recommendation system

# %% [markdown]
# ## 1. Import Libraries
# First, import the pandas, numpy and sklearn libraries

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction import text
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## 2. Import Dataset
# To create the recommendation system, I will be using the "Netflix Movies and TV Shows 2021" dataset from Kaggle. This dataset contains 13 features and approximately 6,000 observations.
#
# https://www.kaggle.com/datasets/satpreetmakhija/netflix-movies-and-tv-shows-2021
#
# I am following a tutorial by Aman Kharwal on how to build this recommendation system.
#
# https://thecleverprogrammer.com/2022/07/05/netflix-recommendation-system-using-python/

# %%
data = pd.read_csv("netflixData.csv")

# %% [markdown]
# ## 3. Exploratory Data Analysis
# First, take a look at the dataset to uncover information such as the number of observations, the types of variables, and look at any missing values.

# %%
data.shape
# Out:
# (5967, 13)

# %%
data.info()

# %%
data.isnull().sum()
# Out:
# Show Id                  0
# Title                    0
# Description              0
# Director              2064
# Genres                   0
# Cast                   530
# Production Country     559
# Release Date             3
# Rating                   4
# Duration                 3
# Imdb Score             608
# Content Type             0
# Date Added            1335
# dtype: int64

# %% [markdown]
# The dataset has 13 variables and 5967 observations. Additionally, only 5 of the attributes have zero null values. For the recommender system I will only be using title, description, genres, and content type. There are no null values for these attributes.
#
# Now lets look more closely at these 4 attributes.

# %%
# Select only the columns that we will be using for the recommendation system
data = data[["Title", "Description", "Genres", "Content Type"]]

# Confirm there are no null values for the selected attributes
data.isnull().sum()
# Out:
# Title           0
# Description     0
# Genres          0
# Content Type    0
# dtype: int64

# %% [markdown]
# Lets take a look at the first few rows of the dataset to see if there is any obvious cleaning that has to be done before getting to building the recommendation system.

# %%
data.head(n=10)
# Out:
#                            Title  \
# 0                       (Un)Well
# 1                         #Alive
# 2  #AnneFrank - Parallel Stories
# 3                       #blackAF
# 4               #cats_the_mewvie
# 5              #FriendButMarried
# 6            #FriendButMarried 2
# 7                   #realityhigh
# 8                      #Rucker50
# 9                        #Selfie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
# 5  Pining for his high school crush for years, a ...
# 6  As Ayu and Ditto finally transition from best ...
# 7  When nerdy high schooler Dani finally attracts...
# 8  This documentary celebrates the 50th anniversa...
# 9  Two days before their final exams, three teen ...
#
#                                            Genres Content Type
# 0                                      Reality TV      TV Show
# 1  Horror Movies, International Movies, Thrillers        Movie
# 2             Documentaries, International Movies        Movie
# 3                                     TV Comedies      TV Show
# 4             Documentaries, International Movies        Movie
# 5   Dramas, International Movies, Romantic Movies        Movie
# 6   Dramas, International Movies, Romantic Movies        Movie
# 7                                        Comedies        Movie
# 8                    Documentaries, Sports Movies        Movie
# 9          Comedies, Dramas, International Movies        Movie

# %% [markdown]
# As you can see, there are no null values, but there is some cleaning to do. First, the titles contain "#" which should be removed. I will also remove stop words from the titles so that tehy can be used to create the recommendation system.

# %% [markdown]
# ## 4. Data Preparation
# ### 4a Clean Title
# To use the Title of a show/movie in the recommender model, it needs to be cleaned. This means removing stop words and removing characters that can cause inaccuracies in the model. I will use the nltk package to remove stop words from the Title feature, and use the regular expressions to remove non-alphabet characters such as brackets, numbers and extra whitespaces.

# %%
# Import nltk library, download stopwords, and set the language
# for  stopwords to English

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
stop_words = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to /Users/kayla/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
import string
stemmer = nltk.SnowballStemmer("english")

'''
Side note: the ? inside some of the expressions means non-greedy,
ie. match as few characters as possible, so if there is a smaller
set of text that matches the regex within a larger set of text that
also matches the regex, only the smaller set will be removed
(ie. fewer characters).
'''

# clean(text) consumes a string and removes all non-alphabet characters
# as well as hyperlinks.
# It also removes stopwords and stems words by removing affixes.


def clean(text):
    text = str(text).lower()                                            # convert text to lowercase
    text = re.sub('\[.*?\]', '', text)                                  # remove any text in square brackets (including the brackets)
    text = re.sub('https?://\S+|www\.\S+', '', text)                    # removes hyperlinks
    text = re.sub('<.*?>+', '', text)                                   # remove any text in <> brackets (including the brackets)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)     # remove punctuation
    text = re.sub('\n', '', text)                                       # remove newlines
    text = re.sub('\w*\d\w*', '', text)                                 # remove any words that contain numbers in them (at the beginning, middle or end) 
    text = [word for word in text.split(' ') if word not in stop_words] # loop through the text and remove stop words, placing each non-stopword into a list
    text = [stemmer.stem(word) for word in text]                        # stem the remaining words
    text=" ".join(text)                                                 # join the words back together to reform the title after all the modifications above are made
    return text

# %%
# apply clean function to title
data["Title"] = data["Title"].apply(clean)
data.head(n=10)
# Out:
#                        Title  \
# 0                      unwel
# 1                       aliv
# 2  annefrank  parallel stori
# 3                    blackaf
# 4               catsthemewvi
# 5             friendbutmarri
# 6            friendbutmarri
# 7                realityhigh
# 8
# 9                      selfi
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
# 5  Pining for his high school crush for years, a ...
# 6  As Ayu and Ditto finally transition from best ...
# 7  When nerdy high schooler Dani finally attracts...
# 8  This documentary celebrates the 50th anniversa...
# 9  Two days before their final exams, three teen ...
#
#                                            Genres Content Type
# 0                                      Reality TV      TV Show
# 1  Horror Movies, International Movies, Thrillers        Movie
# 2             Documentaries, International Movies        Movie
# 3                                     TV Comedies      TV Show
# 4             Documentaries, International Movies        Movie
# 5   Dramas, International Movies, Romantic Movies        Movie
# 6   Dramas, International Movies, Romantic Movies        Movie
# 7                                        Comedies        Movie
# 8                    Documentaries, Sports Movies        Movie
# 9          Comedies, Dramas, International Movies        Movie

# %%
data.Title.sample(10)
# Out:
# 273                     alia grace
# 5235                   surgeon cut
# 196                 action replayi
# 5470                       traitor
# 4693                         bridg
# 1721               one second next
# 398                         apostl
# 3869                           ray
# 2723    lil peep everybodi everyth
# 5642                 vampir knight
# Name: Title, dtype: object

# %% [markdown]
# The clean function did a good job of removing characters that would cause problems for the recommender system. One problem I noticed is that the stemmer stems some words that don't need to be stemmed. For example "alive" is stemmed to "aliv" and "chocolate" is stememd to "chocol". For now I will keep the stemmer, but in the fiture I might experiment with other stemmers to compare.

# %% [markdown]
# ### 4b Remove Blank Titles
# Since stopwords, special characters and numbers are removed by the clean function, some of the titles may end up being blank. For example, the show "The 100" contains only a stopword and a number, so after applying the clean function we will end up with an empty string. These movies/shows will be useless for the recommendation system, so I will remove them from the dataset.

# %%
# let's take a look at the titles that end up blank after applying clean

data.loc[data["Title"] == ""]
# Out:
#      Title                                        Description  \
# 8           This documentary celebrates the 50th anniversa...
# 19          After an awful accident, a couple admitted to ...
# 22          In this thought-provoking documentary, scholar...
# 27          A farmer pens a confession admitting to his wi...
# 28          In this dark alt-history thriller, a naïve law...
# 29          Archival video and new interviews examine Mexi...
# 30          Seeking her independence, a young woman moves ...
# 34          This intimate documentary follows rock star Ar...
# 36          When a flood of natural disasters begins to de...
# 37          In a social experiment, a group of daughters s...
# 40          When an army recruit is found dead, his fellow...
# 48          In a future where the elite inhabit an island ...
# 49          Stranded when the Earth is suddenly destroyed ...
# 56          A genetics professor experiments with a treatm...
# 58          Hoping to reunite with a dying friend, two lon...
# 62          Seeking to uncover the truth about his past, a...
# 63          To keep the band together, Selly tries to earn...
# 69          This film sheds light on sexual harassment in ...
# 74          After a devastating earthquake hits Mexico Cit...
# 79          Shy Natsu awakens as part of a group chosen to...
# 213         Wholesome college freshman Tessa Young thinks ...
# 287         After falling for a guest, an unsuspecting hot...
# 294         Two strangers meet on a dating app and experie...
# 423         A beautiful tomb raider and her crew hunt for ...
# 567         They were the boy band to beat until fame tore...
# 568         After reconnecting with their girlhood crushes...
# 583         Four female friends in the fast-paced city of ...
# 627         After a mysterious disease kills every residen...
# 1349        A ruthless crime boss and drug lord is nabbed ...
# 1350        With Asia under his complete control, criminal...
# 2203        In the midst of a field exercise operating I-M...
# 2445        When her uptight new boss and landlord starts ...
# 3512        After a chance phone call leads to daily conve...
# 3543        A couple must endure a self-imposed quarantine...
# 4156        From the creators of "The Matrix" and "Babylon...
# 4210        An undercover assignment to expose a drug ring...
# 4211        Under pressure from her family and friends to ...
# 4372        The arrival of an enigmatic struggling musicia...
# 4567        Still desperate to find his granddaughter near...
# 4598        A century after Earth was devastated by a nucl...
# 4601        A Secret Service agent is drawn into a terrori...
# 4604        This docuseries disputes the Mexican governmen...
# 4605        4400 people who vanished over the course of fi...
# 4936        A fugitive soldier gets swept up in personal a...
# 5095        When a graduate student elopes with a plucky r...
# 5413        Just as Simone works up the courage to tell he...
# 5691        This glossy ensemble drama juxtaposes the live...
# 5694        The new Head of Values at the BBC deals with r...
# 5768        Desperate to secure funding for her med tech s...
# 5777        Four individuals at a crossroads in life are g...
# 5819        After his compatriots are murdered by Russian ...
# 5830        A young prosecutor is assigned a career-making...
# 5906        Obsessed with an aspiring writer, a charming b...
# 5933        Fading music biz veteran Zé realizes he has ju...
#
#                                                  Genres Content Type
# 8                          Documentaries, Sports Movies        Movie
# 19                  Horror Movies, International Movies        Movie
# 22                                        Documentaries        Movie
# 27                                    Dramas, Thrillers        Movie
# 28    Crime TV Shows, International TV Shows, TV Dramas      TV Show
# 29    Crime TV Shows, Docuseries, International TV S...      TV Show
# 30         Horror Movies, Independent Movies, Thrillers        Movie
# 34    Documentaries, International Movies, Sports Mo...        Movie
# 36                 Action & Adventure, Sci-Fi & Fantasy        Movie
# 37                         British TV Shows, Reality TV      TV Show
# 40                  Horror Movies, International Movies        Movie
# 48    International TV Shows, TV Dramas, TV Sci-Fi &...      TV Show
# 49      Independent Movies, Sci-Fi & Fantasy, Thrillers        Movie
# 56      International TV Shows, TV Dramas, TV Mysteries      TV Show
# 58                 Comedies, Dramas, Independent Movies        Movie
# 62      International TV Shows, TV Dramas, TV Thrillers      TV Show
# 63                       Comedies, International Movies        Movie
# 69     Dramas, Independent Movies, International Movies        Movie
# 74                         Dramas, International Movies        Movie
# 79                 Anime Series, International TV Shows      TV Show
# 213                             Dramas, Romantic Movies        Movie
# 287   Action & Adventure, Comedies, International Mo...        Movie
# 294              Comedies, Dramas, International Movies        Movie
# 423                            Horror Movies, Thrillers        Movie
# 567   International TV Shows, Romantic TV Shows, TV ...      TV Show
# 568   International TV Shows, Romantic TV Shows, TV ...      TV Show
# 583   International TV Shows, Romantic TV Shows, TV ...      TV Show
# 627     International TV Shows, TV Dramas, TV Mysteries      TV Show
# 1349           Action & Adventure, International Movies        Movie
# 1350  Action & Adventure, International Movies, Musi...        Movie
# 2203               Anime Series, International TV Shows      TV Show
# 2445  International TV Shows, Romantic TV Shows, TV ...      TV Show
# 3512   Dramas, Independent Movies, International Movies        Movie
# 3543        Dramas, Independent Movies, Romantic Movies        Movie
# 4156            Crime TV Shows, TV Dramas, TV Mysteries      TV Show
# 4210  Crime TV Shows, International TV Shows, TV Dramas      TV Show
# 4211      Dramas, International Movies, Romantic Movies        Movie
# 4372             Dramas, Romantic Movies, Sports Movies        Movie
# 4567            Dramas, International Movies, Thrillers        Movie
# 4598  TV Action & Adventure, TV Dramas, TV Sci-Fi & ...      TV Show
# 4601                                 Action & Adventure        Movie
# 4604  Crime TV Shows, Docuseries, International TV S...      TV Show
# 4605       TV Dramas, TV Mysteries, TV Sci-Fi & Fantasy      TV Show
# 4936  International TV Shows, Korean TV Shows, Roman...      TV Show
# 5095      Dramas, International Movies, Romantic Movies        Movie
# 5413       Comedies, International Movies, LGBTQ Movies        Movie
# 5691                            Dramas, Romantic Movies        Movie
# 5694                      British TV Shows, TV Comedies      TV Show
# 5768                            TV Dramas, TV Thrillers      TV Show
# 5777                  International TV Shows, TV Dramas      TV Show
# 5819                    International Movies, Thrillers        Movie
# 5830            Dramas, International Movies, Thrillers        Movie
# 5906       Crime TV Shows, Romantic TV Shows, TV Dramas      TV Show
# 5933                                           Kids' TV      TV Show

# %% [markdown]
# Lets see how many blank titles there are in the dataset after cleaning the titles.

# %%
data["Title"].loc[data.Title == ''].count()
# Out:
# 54

# %% [markdown]
# There are 54 blank titles, which will not provide good recommendations, so I will remove these observations from the dataset.

# %%
data.drop(data[data["Title"] == ''].index, inplace=True)
data["Title"].loc[data.Title == ''].count()
# Out:
# 0

# %% [markdown]
# ### 4c Remove Duplicate Titles
# For the recommender, we want to remove duplicate rows so that we do not get the same movie recommended either as a recommendation for itself or appear twice in a recommendation for another movie.

# %%
data["Title"].duplicated().value_counts()
# Out:
# False    5689
# True      224
# Name: Title, dtype: int64

# %%
indices = pd.Series(data.index, index=data['Title']).drop_duplicates()

# %% [markdown]
# ## 5. Building the Recommender System
# I will use Cosine Similarity to recommend similar movies and tv shows to the user based on the Genres column.
#
# Here I will use the TfidfVectorizer to convert the genres column into a matrix of TF-IDF features. TF-IDF stands for term frequency- inverse document frequency. Essentially, this calculates the importance of a word based on the number of times the word appears in a corpus. The more frequently a term appears in the corpous, the less importance it is given, and hence the lower the tfidf score assigned to that word.

# %%
feature = data["Genres"].tolist()

# Convert the genres column into a matrix of TF-IDF features
tfidf = text.TfidfVectorizer(input=feature, stop_words="english")
tfidf_matrix = tfidf.fit_transform(feature)
similarity = cosine_similarity(tfidf_matrix)

# %%
data["Title"].duplicated().value_counts()
# Out:
# False    5689
# True      224
# Name: Title, dtype: int64

# %% [markdown]
# Finally, I will write the function netflix_recommendation to recommend shows and movies to users based on a given show/movie.

# %%
def netflix_recommendation(title, similarity=similarity):
    index = indices[title]
    similarity_scores = list(enumerate(similarity[index]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similarity_scores = similarity_scores[0:11]
    movieindices = [i[0] for i in similarity_scores if i[0] != index]
    return data[['Title']].iloc[movieindices[:10]]

# %% [markdown]
# ## 6. Use the Recommender to Recommend Shows and Movies
# Now that the recommender is built, I will use it to recommend movies and tv shows for some examples.

# %%
netflix_recommendation("witcher")
# Out:
#                    Title
# 164         special love
# 311           alway mayb
# 1002       christma view
# 1624  final found someon
# 2295         isa pa feel
# 2444                 way
# 2579       krishna leela
# 3265        amnesia girl
# 4057     sakal mage tayo
# 4848    girl allerg wifi

# %%
netflix_recommendation("elit")
# Out:
#                Title
# 465   await instruct
# 5844        winchest
# 2114            horn
# 1139    crimson peak
# 1195      dark light
# 5840           wildl
# 4516      sweetheart
# 209           aerial
# 5292    wander earth
# 1358    doom annihil

# %%
netflix_recommendation("manifest")
# Out:
#                            Title
# 3                        blackaf
# 285                   washington
# 417               arrest develop
# 434   astronomi club sketch show
# 451  aunti donna big ol hous fun
# 656                    big mouth
# 752              bojack horseman
# 805                 brew brother
# 935                     champion
# 937                chappell show

# %% [markdown]
# ## 6. Conclusions
# Overall, the recommender does an okay job of recommending movies and shows based on the given title, although there are some pitfalls.
#
# First, cleaning the Titles makes it hard for the user to input shows/movies to the recommender because they have to know what the new title would be after cleaning. For example, the show "Elite" becomes "elit" after applying to clean function. In the future, I would like to fix this so that the user can type the title exactly as it is and get recommendations.
#
# Second, the recommendations are not great as they only look at the list of genres for each movie to find similar ones. In a future iteration I would like to use other features to recommend similar movies such as title, description, director, and maybe cast.
